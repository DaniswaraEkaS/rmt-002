# %% [markdown]
# [data](https://github.com/fahmimnalfrzki/Dataset/raw/refs/heads/main/insurance.csv)

# %% [markdown]
# Import dataset

# %%
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/fahmimnalfrzki/Dataset/refs/heads/main/insurance.csv
# Out:
# --2024-11-13 10:13:36--  https://raw.githubusercontent.com/fahmimnalfrzki/Dataset/refs/heads/main/insurance.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54289 (53K) [text/plain]
# Saving to: ‘insurance.csv’
#
# insurance.csv       100%[===================>]  53.02K  --.-KB/s    in 0.05s
#
# 2024-11-13 10:13:37 (987 KB/s) - ‘insurance.csv’ saved [54289/54289]

# %%
pd.read_csv('insurance.csv')
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df = pd.read_csv('insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Lakukan eksplorasi sederhana (menampilkan 5 data teratas, 5 data terbawah, info data, statistik deskriptif data)

# %%
df.head() # menampilkan 5 data teratas
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.tail() # menampilan 5 data terbawah
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.info() # menampilkan info data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe() # menampilan statistik deskriptif data
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# Urutkan data berdasarkan usia! (descending)

# %%
df.sort_values(by='age',ascending=False)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 335    64    male  34.500         0     no  southwest  13822.80300
# 603    64  female  39.050         3     no  southeast  16085.12750
# 752    64    male  37.905         0     no  northwest  14210.53595
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 534    64    male  40.480         0     no  southeast  13831.11520
# ...   ...     ...     ...       ...    ...        ...          ...
# 942    18  female  40.185         0     no  northeast   2217.46915
# 46     18  female  38.665         2     no  northeast   3393.35635
# 295    18    male  22.990         0     no  northeast   1704.56810
# 50     18  female  35.625         0     no  northeast   2211.13075
# 648    18    male  28.500         0     no  northeast   1712.22700
#
# [1338 rows x 7 columns]

# %% [markdown]
# Urutkan data berdasarkan charges! (ascending)

# %%
df.sort_values(by='charges',ascending=True)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 940    18    male  23.210         0     no  southeast   1121.87390
# 808    18    male  30.140         0     no  southeast   1131.50660
# 1244   18    male  33.330         0     no  southeast   1135.94070
# 663    18    male  33.660         0     no  southeast   1136.39940
# 22     18    male  34.100         0     no  southeast   1137.01100
# ...   ...     ...     ...       ...    ...        ...          ...
# 819    33  female  35.530         0    yes  northwest  55135.40209
# 577    31  female  38.095         1    yes  northeast  58571.07448
# 1230   52    male  34.485         3    yes  northwest  60021.39897
# 1300   45    male  30.360         0    yes  southeast  62592.87309
# 543    54  female  47.410         0    yes  southeast  63770.42801
#
# [1338 rows x 7 columns]

# %% [markdown]
# Urutkan data berdasarkan region dan charges

# %%
df.sort_values(by=['region','charges'])
# Out:
#       age     sex     bmi  children smoker     region      charges
# 172    18    male  15.960         0     no  northeast   1694.79640
# 1212   18    male  21.470         0     no  northeast   1702.45530
# 295    18    male  22.990         0     no  northeast   1704.56810
# 1041   18    male  23.085         0     no  northeast   1704.70015
# 121    18    male  23.750         0     no  northeast   1705.62450
# ...   ...     ...     ...       ...    ...        ...          ...
# 328    64  female  33.800         1    yes  southwest  47928.03000
# 39     60    male  39.900         0    yes  southwest  48173.36100
# 175    63  female  37.700         0    yes  southwest  48824.45000
# 34     28    male  36.400         1    yes  southwest  51194.55914
# 1146   60    male  32.800         0    yes  southwest  52590.82939
#
# [1338 rows x 7 columns]

# %% [markdown]
# Tampilkan kolom bmi

# %%
df['bmi']
# Out:
# 0       27.900
# 1       33.770
# 2       33.000
# 3       22.705
# 4       28.880
#          ...
# 1333    30.970
# 1334    31.920
# 1335    36.850
# 1336    25.800
# 1337    29.070
# Name: bmi, Length: 1338, dtype: float64

# %% [markdown]
# Tampilkan kolom jenis kelamin dan kebiasaan merokok

# %%
df[['sex','smoker']]
# Out:
#          sex smoker
# 0     female    yes
# 1       male     no
# 2       male     no
# 3       male     no
# 4       male     no
# ...      ...    ...
# 1333    male     no
# 1334  female     no
# 1335  female     no
# 1336  female     no
# 1337  female    yes
#
# [1338 rows x 2 columns]

# %% [markdown]
# Tampilkan baris ke-50

# %%
df.iloc[50]
# Out:
# age                 18
# sex             female
# bmi             35.625
# children             0
# smoker              no
# region       northeast
# charges     2211.13075
# Name: 50, dtype: object

# %% [markdown]
# Tampilkan data hanya dari baris ke-10 sampai ke-45

# %%
df.iloc[10:46]
# Out:
#     age     sex     bmi  children smoker     region      charges
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# 13   56  female  39.820         0     no  southeast  11090.71780
# 14   27    male  42.130         0    yes  southeast  39611.75770
# 15   19    male  24.600         1     no  southwest   1837.23700
# 16   52  female  30.780         1     no  northeast  10797.33620
# 17   23    male  23.845         0     no  northeast   2395.17155
# 18   56    male  40.300         0     no  southwest  10602.38500
# 19   30    male  35.300         0    yes  southwest  36837.46700
# 20   60  female  36.005         0     no  northeast  13228.84695
# 21   30  female  32.400         1     no  southwest   4149.73600
# 22   18    male  34.100         0     no  southeast   1137.01100
# ...
